# %%
import matplotlib.pyplot as plt
x=['Python',"C","C++","Java"]
y=[75,25,35,60]
plt.title("Practice",fontsize=25,color='r')
plt.xlabel("Language",fontsize=15,color="g")
plt.ylabel("Demanding",fontsize=30,color="g")
c=["y","r","g","b"]
plt.bar(x,y,color=c,width=0.8)
plt.legend(x)
plt.savefig("LIne")
plt.show()
